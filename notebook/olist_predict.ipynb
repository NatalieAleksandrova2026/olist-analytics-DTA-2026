# %% [markdown]
# <a href="https://colab.research.google.com/github/NatalieAleksandrova2026/olist-analytics-DTA-2026/blob/main/notebook/olist_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Part 3. Python: Simple Forecasting and Recommendations
